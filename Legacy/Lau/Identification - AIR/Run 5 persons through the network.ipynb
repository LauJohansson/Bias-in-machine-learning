# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# In[1]:

# %%
import numpy as np
from tqdm.notebook import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
#import torchvision.datasets as datasets
from torch.utils.data import DataLoader
#import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch.optim as optim
from IPython.display import clear_output

# %%
import pandas as pd 
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib.patches as mpatches
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# rom google.colab import drive

# %%
from sklearn.model_selection import KFold

# %%
from datetime import datetime

# %%
import pytz
import random

# %%
import os
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# In[13]:

# %% [markdown]
# ATH="/content/drive/My Drive/Kandidat speciale/500 - Notebooks/models/all races_CV50/"

# %% [markdown]
# ## AIR ###

# %%
AIR=True
file_name="Fall_count_clusterOHE_std.csv"
full_file_path="/restricted/s164512/G2020-57-Aalborg-bias/data_air/"+file_name

# %% [markdown]
# itel_mitigation="testAIR"

# %%
titel_mitigation="original"
PATH_orig="/restricted/s164512/G2020-57-Aalborg-bias/lau/FFNN_ohe/models/"+titel_mitigation+"/"

# %%
y_col_name="Fall"
X_col_names=['Gender',
'BirthYear',
'LoanPeriod',
'NumberAts',
'Ats_Polstring',
'Ats_Mobilitystokke',
'Ats_Belysning',
'Ats_Underlag',
'Ats_ToiletforhÃ¸jereStativ',
'Ats_Signalgivere',
'Ats_EldrevneKÃ¸restole',
'Ats_ForstÃ¸rrelsesglas',
'Ats_NÃ¸dalarmsystemer',
'Ats_MobilePersonlÃ¸ftere',
'Ats_TrappelifteMedPlatforme',
'Ats_BadekarsbrÃ¦tter',
'Ats_Albuestokke',
'Ats_MaterialerOgRedskaberTilAfmÃ¦rkning',
'Ats_RyglÃ¦n',
#'Ats_0',
'Ats_GanghjÃ¦lpemidlerStÃ¸tteTilbehÃ¸r',
'Ats_StÃ¸ttebÃ¸jler',
'Ats_Lejringspuder',
'Ats_StrÃ¸mpepÃ¥tagere',
'Ats_DÃ¸rtrin',
'Ats_Spil',
'Ats_BordePÃ¥Stole',
'Ats_Drejeskiver',
'Ats_Toiletstole',
'Ats_LÃ¸ftereStationÃ¦re',
'Ats_MadmÃ¥lingshjÃ¦lpemidler',
'Ats_Fodbeskyttelse',
'Ats_StÃ¥lÃ¸ftere',
'Ats_Stole',
'Ats_Sengeborde',
'Ats_Toiletter',
'Ats_ToiletforhÃ¸jereFaste',
'Ats_PÃ¥klÃ¦dning',
'Ats_Brusere',
'Ats_VÃ¦vsskadeLiggende',
'Ats_DÃ¸rÃ¥bnere',
'Ats_ServeringAfMad',
'Ats_TrappelifteMedSÃ¦der',
'Ats_SÃ¦derTilMotorkÃ¸retÃ¸jer',
'Ats_KÃ¸restoleManuelleHjÃ¦lper',
'Ats_Gangbukke',
'Ats_Rollatorer',
'Ats_TryksÃ¥rsforebyggendeSidde',
'Ats_Fastnettelefoner',
'Ats_BÃ¦kkener',
'Ats_VendehjÃ¦lpemidler',
'Ats_Sanseintegration',
'Ats_KÃ¸restolsbeskyttere',
'Ats_Arbejdsstole',
'Ats_LÃ¸ftesejl',
'Ats_KÃ¸restoleForbrÃ¦ndingsmotor',
'Ats_LÃ¸ftestropper',
'Ats_Stiger',
'Ats_TransportTrapper',
'Ats_DrivaggregaterKÃ¸restole',
'Ats_EmballageÃ¥bnere',
'Ats_ToiletforhÃ¸jereLÃ¸se',
'Ats_HÃ¥rvask',
'Ats_PersonlÃ¸ftereStationÃ¦re',
'Ats_Madrasser',
'Ats_VinduesÃ¥bnere',
'Ats_LÃ¦sestativer',
'Ats_KÃ¸restoleManuelleDrivringe',
'Ats_SÃ¦depuder',
'Ats_UdstyrCykler',
'Ats_Karkludsvridere',
'Ats_Vaskeklude',
'Ats_Sengeudstyr',
'Ats_MadlavningshjÃ¦lpemidler',
'Ats_Skohorn',
'Ats_GribetÃ¦ngerManuelle',
'Ats_Hvilestole',
'Ats_EldrevneKÃ¸restoleStyring',
'Ats_BÃ¦rehjÃ¦lpemidlerTilKÃ¸restole',
'Ats_LÃ¸ftegalgerSeng',
'Ats_HÃ¸reforstÃ¦rkere',
'Ats_Kalendere',
'Ats_Stokke',
'Ats_LÃ¸ftegalger',
'Ats_Ure',
'Ats_StÃ¸ttegrebFlytbare',
'Ats_Forflytningsplatforme',
'Ats_RamperFaste',
'Ats_RygehjÃ¦lpemidler',
'Ats_PersonvÃ¦gte',
'Ats_ManÃ¸vreringshjÃ¦lpemidler',
'Ats_OvertÃ¸j',
'Ats_Lydoptagelse',
'Ats_Gangborde',
'Ats_StÃ¥stÃ¸ttestole',
'Ats_RamperMobile',
'Ats_BÃ¦rehjÃ¦lpemidler',
'Ats_BadekarssÃ¦der',
'Ats_Siddemodulsystemer',
'Ats_Videosystemer',
'Ats_Siddepuder',
'Ats_Sengeheste',
'Ats_Stolerygge',
'Ats_Rulleborde',
'Ats_SengeforlÃ¦ngere',
'Ats_Madningsudstyr',
'Ats_Brusestole',
'Ats_Flerpunktsstokke',
'Ats_SengebundeMedMotor',
'Ats_Cykler',
'Ats_CykelenhederKÃ¸restole',
'Ats_Stokkeholdere',
'Ats_ToiletarmstÃ¸tter',
'Ats_Coxitstole',
'Ats_ToiletsÃ¦der',
'Ats_Rebstiger',
'Ats_ForhÃ¸jerklodser',
'Cluster_0',
'Cluster_1',
'Cluster_2',
'Cluster_3',
'Cluster_4',
'Cluster_5',
'Cluster_6',
'Cluster_7',
'Cluster_8',
'Cluster_9',
'Cluster_10',
'Cluster_11',
'Cluster_12',
'Cluster_13',
'Cluster_14',
'Cluster_15',
'Cluster_16',
'Cluster_17',
'Cluster_18',
'Cluster_19']
#X_col_names = [col for col in X_col_names if col not in leave_out ]

# %%
procted_col_name="Gender"

# %% [markdown]
# #### COMPASS ####

# %% [markdown]
# IR=False

# %% [markdown]
# itel_mitigation="testCOMPASS"<br>
# ATH_orig="/restricted/s164512/G2020-57-Aalborg-bias/lau/FFNN/models/"+titel_mitigation+"/"

# %% [markdown]
# ull_file_path = 'https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv'

# %% [markdown]
# _col_name="is_recid"<br>
# _col_names=['remember_index','sex','age','race', 'juv_fel_count','juv_misd_count','juv_other_count','priors_count',"c_charge_desc","c_charge_degree"]

# %% [markdown]
# rocted_col_name="race"

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[14]:

# %%
n_nodes=500

# %%
batch_size=40
epochs=400
p_drop=0.4

# %%
optim_type="Adam" #SGD
lr=0.001 #0.001 er godt
wd=0.003 #0.001 er godt

# %%
n_feat=len(X_col_names)
output_dim=1 #binary

# %% [markdown]
# In[15]:

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.fully_connected1 = nn.Sequential(
            nn.Linear(n_feat,n_nodes),
            nn.ReLU(),
            nn.BatchNorm1d(n_nodes),
            nn.Dropout(p_drop)
            )
        self.fully_connectednew = nn.Sequential(
            nn.Linear(n_nodes,n_nodes),
            nn.ReLU(),
            nn.BatchNorm1d(n_nodes),
            nn.Dropout(p_drop)
            )
        self.fully_connectednew1 = nn.Sequential(
            nn.Linear(n_nodes,n_nodes),
            nn.ReLU(),
            nn.BatchNorm1d(n_nodes),
            nn.Dropout(p_drop)
            )
        self.fully_connectednew2 = nn.Sequential(
            nn.Linear(n_nodes,n_nodes),
            nn.ReLU(),
            nn.BatchNorm1d(n_nodes),
            nn.Dropout(p_drop)
            )
        self.fully_connectednew3 = nn.Sequential(
            nn.Linear(n_nodes,n_nodes),
            nn.ReLU(),
            nn.BatchNorm1d(n_nodes),
            nn.Dropout(p_drop)
            )

# %%
        self.fully_connected2 = nn.Sequential(
            nn.Linear(n_nodes,output_dim),
            #nn.Softmax(dim = 1)
            nn.Sigmoid()
            )
    def forward(self, x):
      #reshaping x so it becomes flat, except for the first dimension (which is the minibatch)
        #x = x.view(x.size(0),-1)
        x = self.fully_connected1(x)
        x = self.fully_connectednew(x)
        x = self.fully_connectednew1(x)
        x = self.fully_connectednew2(x)
        x = self.fully_connectednew3(x)
        x = self.fully_connected2(x)
        return x

# %% [markdown]
# In[16]:

# %% [markdown]
# rom utils_copy import *

# %% [markdown]
# # Get the five persons

# %% [markdown]
# In[17]:

# %% [markdown]
# f=pd.read_csv(full_file_path).drop(columns=["Unnamed: 0"])<br>
# f=df[X_col_names+[y_col_name]]<br>
# f_5_persons=df.sample(6,random_state=7)<br>
# f_5_persons=df_5_persons[X_col_names+[y_col_name]]<br>
# f_5_persons.to_csv("/restricted/s164512/G2020-57-Aalborg-bias/6 citizens/6_cit_data.csv")

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[18]:

# %%
df_5_persons=pd.read_csv("/restricted/s164512/G2020-57-Aalborg-bias/6 citizens/6_cit_data.csv")

# %% [markdown]
# In[19]:

# %%
df_5_persons_nonstd=pd.read_csv("/restricted/s164512/G2020-57-Aalborg-bias/data_air/Fall_count_clusterOHE.csv").drop(columns=["Unnamed: 0"])
df_5_persons_nonstd=df_5_persons_nonstd.iloc[list(df_5_persons["Unnamed: 0"])]
df_5_persons_nonstd=df_5_persons_nonstd.reset_index(drop=True)
df_5_persons_nonstd.to_csv("/restricted/s164512/G2020-57-Aalborg-bias/6 citizens/6_cit_data_nonstd.csv")

# %% [markdown]
# In[20]:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# In[21]:

# %%
all_cols=X_col_names+[y_col_name]
all_cols=all_cols+["output"]
all_cols=all_cols+["output_prob"]
all_cols=all_cols+["Model"]

# %% [markdown]
# In[22]:

# %%
df_predicted=pd.DataFrame([],columns=all_cols)

# %% [markdown]
# In[23]:

# %%
for i in range(50):
    seedName="model"+str(i)
    PATH=PATH_orig+seedName+"/"
    model1 = Network().to(device)
    model1.load_state_dict(torch.load(PATH+'_FFNN_model_local.pth'))
    
    df_predicted_subset=df_5_persons.copy()
    
    X_numpy=np.array(df_predicted_subset[X_col_names])
    X_torch=torch.tensor(X_numpy)
    y_pred = model1(X_torch.float().to(device))
    
    list_of_output=[round(a.item(),0) for a in y_pred.detach().cpu()]
    list_of_output_prob=[a.item() for a in y_pred.detach().cpu()]
    df_predicted_subset["output"]=list_of_output
    df_predicted_subset["output_prob"]=list_of_output_prob
    
    df_predicted_subset["Model"]=seedName
    
    df_predicted_subset=df_predicted_subset.reset_index(drop=True)
    
    df_predicted=pd.concat([df_predicted,df_predicted_subset],axis=0,sort=False)
    
    
#df_predicted=df_predicted.reset_index(drop=True)

# %% [markdown]
# In[24]:

# %%
df_predicted.to_csv("/restricted/s164512/G2020-57-Aalborg-bias/6 citizens/FFNN_predictions.csv")

# %% [markdown]
# In[160]:

# %% [markdown]
# In[ ]:
