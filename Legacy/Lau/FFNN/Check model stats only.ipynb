# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# # Imports

# %% [markdown]
# In[1]:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# In[2]:

# %%
from utils import *

# %% [markdown]
# # Files

# %% [markdown]
# In[3]:

# %%
titel_mitigation="test23may"
PATH_orig="/restricted/s164512/G2020-57-Aalborg-bias/lau/FFNN/models/"+titel_mitigation+"/"
procted_col_name="Gender"

# %% [markdown]
# In[4]:

# %%
df_local_all=pd.read_csv(PATH_orig+"/FFNN_metrics_crossvalidated_global_all.csv")
df_local_proc=pd.read_csv(PATH_orig+"FFNN_metrics_crossvalidated_local_"+procted_col_name+".csv")

# %% [markdown]
# In[5]:

# %%
local_all_bar=sns.barplot(data=df_local_all[df_local_all["Measure"].isin(["FPR","FNR","TPR","TNR"])],x="Group", y="Value", ci=95,hue="Measure")
local_all_bar.set_title('Global all')
plt.show()

# %% [markdown]
# In[6]:

# %%
local_proc_bar=sns.barplot(data=df_local_proc[df_local_proc["Measure"].isin(["FPR","FNR","TPR","TNR"])],x="Group", y="Value", ci=95,hue="Measure")
local_proc_bar.set_title('Local protected: '+procted_col_name)
plt.show()

# %% [markdown]
# # All stats (chose yourself)

# %% [markdown]
# In[7]:

# %% [markdown]
# # USE ALL DATA<br>
# ile_name="fall.csv"<br>
# ull_file_path="/restricted/s164512/G2020-57-Aalborg-bias/data_air/"+file_name

# %% [markdown]
# #USE SMALL TEST<br>
# itel_mitigation=titel_mitigation<br>
# ATH_orig="/restricted/s164512/G2020-57-Aalborg-bias/lau/FFNN/models/"+titel_mitigation+"/"

# %%
file_name="all_test_data_localmodel.csv"
#file_name="all_test_data_globalmodel.csv"

# %%
full_file_path=PATH_orig+file_name

# %%
print("PATH_orig:",PATH_orig)
print("PATH to file:",full_file_path)

# %% [markdown]
# In[8]:

# %%
y_col_name="Fall"

# %%
X_col_names=['Gender', 'BirthYear', 'Cluster', 'LoanPeriod', 'NumberAts', '1Ats',
       '2Ats', '3Ats', '4Ats', '5Ats', '6Ats', '7Ats', '8Ats', '9Ats', '10Ats',
       '11Ats', '12Ats', '13Ats', '14Ats', '15Ats', '16Ats', '17Ats', '18Ats',
       '19Ats', '20Ats', '21Ats', '22Ats', '23Ats', '24Ats', '25Ats', '26Ats',
       '27Ats', '28Ats', '29Ats', '30Ats', '31Ats', '32Ats', '33Ats', '34Ats',
       '35Ats', '36Ats', '37Ats', '38Ats', '39Ats', '40Ats', '41Ats', '42Ats',
       '43Ats', '44Ats', '45Ats', '46Ats', '47Ats', '48Ats', '49Ats', '50Ats',]

# %%
procted_col_name="Gender"

# %%
output_col_name="output"

# %%
unfavourable_name=0 #women=0
favourable_name=1 #men=1

# %% [markdown]
# In[9]:

# %%
df2 = pd.read_csv(full_file_path)

# %% [markdown]
# In[10]:

# %% [markdown]
# et_df_w_metrics(df2,procted_col_name,y_col_name,output_col_name).sort_values(["Gender"])[["Gender","TPR","FPR","TNR","FNR","ACC"]]*100

# %% [markdown]
# In[11]:

# %%
df2_copy=df2.copy()

# %%
mean_age=df2_copy["BirthYear"].mean()

# %%
df2_copy["age_cat_custom"]=df2_copy["BirthYear"].apply(lambda x: "Above mean" if x<mean_age else "Under mean")

# %% [markdown]
# In[12]:

# %%
get_df_w_metrics(df2,procted_col_name,y_col_name,output_col_name).sort_values(["Gender"])[["Gender","TPR","FPR","TNR","FNR","ACC"]]*100

# %% [markdown]
# In[13]:

# %%
get_df_w_metrics(df2_copy,"age_cat_custom",y_col_name,output_col_name)[["age_cat_custom","TPR","FPR","TNR","FNR","ACC"]]*100

# %% [markdown]
# In[14]:

# %%
compare_bias_metrics(df2_copy,"Gender",y_col_name,output_col_name,0,1,True)

# %% [markdown]
# In[15]:

# %%
compare_bias_metrics(df2_copy,"age_cat_custom",y_col_name,output_col_name,"Under mean","Above mean",True)

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:
