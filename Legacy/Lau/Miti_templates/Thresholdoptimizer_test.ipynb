# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# In[1]:

# %% [markdown]
# ip install raiwidgets<br>
# ip install fairlearn<br>
# ip install ipywidgets

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import BinaryLabelDatasetMetric

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import svm
from sklearn.metrics import plot_roc_curve

# %%
from raiwidgets import FairnessDashboard
from fairlearn.widget import FairlearnDashboard

# %% [markdown]
# # Load data

# %% [markdown]
# In[5]:

# %%
merged=pd.read_csv("../../Data_air/dummy_data.csv")

# %% [markdown]
# In[ ]:

# %%
merged=merged.drop(columns=["BorgerId","Unnamed: 0"])

# %% [markdown]
# In[ ]:

# %%
merged=merged[["Birth Year","Fall","Gender"]]

# %% [markdown]
# In[3]:

# %%
import random
merged["Corr_var"]=merged["Fall"].apply(lambda x: random.randint(30,60) if x==1 else random.randint(25,40))

# %% [markdown]
# In[34]:

# %%
merged["Gender_string"]=merged["Gender"].apply(lambda x: "Male" if x==1 else "Female")

# %% [markdown]
# In[19]:

# %%
merged["Fall"].mean()

# %% [markdown]
# In[20]:

# %%
merged.shape

# %% [markdown]
# In[21]:

# %% [markdown]
# erged=merged.head(500)

# %% [markdown]
# # Logistic regression

# %% [markdown]
# In[22]:

# %% [markdown]
# _cols=[name for name in merged.columns.tolist() if name not in ["Fall","BorgerId"]]<br>
# =merged[X_cols]<br>
# =merged["Fall"]

# %%
df_train, df_test = train_test_split(merged, test_size=0.25)

# %%
X_train = df_train.drop(columns=['Fall','Gender_string'], axis=1) #drop Sex (protected) and paymant (y)
X_test = df_test.drop(columns=['Fall','Gender_string'], axis=1)  #drop Sex (protected) and paymant (y)

# %%
y_train = df_train['Fall']
y_test = df_test['Fall']

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %% [markdown]
# In[23]:

# %%
plot_roc_curve(model, X_test, y_test)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)
plt.show()

# %% [markdown]
# In[35]:

# %% [markdown]
# <br>
# FairnessDashboard(<br>
#     sensitive_features=df_test['Gender'],<br>
#     #sensitive_feature_names=df_test['Gender_string'],<br>
#     y_true=df_test['Fall'],<br>
#     y_pred=model.predict(X_test)<br>
# )<br>

# %% [markdown]
# In[36]:

# %%
FairlearnDashboard(sensitive_features=df_test['Gender'],
                   sensitive_feature_names=['BinaryGender'],
                   y_true=df_test['Fall'].tolist(),
                   y_pred=model.predict(X_test))

# %% [markdown]
# # Threshold optimizer

# %% [markdown]
# In[37]:

# %%
from fairlearn.postprocessing import ThresholdOptimizer
#https://fairlearn.org/v0.5.0/api_reference/fairlearn.postprocessing.html

# %% [markdown]
# In[38]:

# %%
optimizer = ThresholdOptimizer(estimator=model, constraints='demographic_parity') #
#optimizer = ThresholdOptimizer(estimator=model, constraints=â€™equalized_odds')
#optimizer = ThresholdOptimizer(estimator=model, constraints=â€™true_positive_rate_parityâ€™)
#optimizer = ThresholdOptimizer(estimator=model, constraints=â€™true_negative_rate_parityâ€™)
#optimizer = ThresholdOptimizer(estimator=model, constraints=â€™false_positive_rate_parityâ€™)
#optimizer = ThresholdOptimizer(estimator=model, constraints=â€™false_negative_rate_parityâ€™)

# %%
optimizer.fit(X_train, y_train, sensitive_features=df_train['Gender'])
from fairlearn.widget import FairlearnDashboard

# %% [markdown]
# In[39]:

# %%
y_pred_optim=optimizer.predict(X_test, sensitive_features=df_test['Gender'])

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %%
from fairlearn.postprocessing import plot_threshold_optimizer

# %% [markdown]
# In[ ]:

# %%
plot_threshold_optimizer(optimizer)

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[40]:

# %%
from raiwidgets import FairnessDashboard

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[41]:

# %% [markdown]
# <br>
# comparison = {<br>
#     'Original model': model.predict(X_test),<br>
#     'TresholdOptimizer': optimizer.predict(X_test, sensitive_features=df_test['Gender'])<br>
# }<br>
# FairnessDashboard(<br>
#     sensitive_features=df_test['Gender'],<br>
#     #sensitive_feature_names=df_test['Gender_string'],<br>
#     y_true=df_test['Fall'],<br>
#     y_pred=comparison<br>
# )<br>

# %% [markdown]
# ## Fairness dashboard<br>
# https://fairlearn.org/v0.5.0/user_guide/assessment.html#fairlearn-dashboard

# %% [markdown]
# In[42]:

# %%
from fairlearn.widget import FairlearnDashboard

# %% [markdown]
# In[43]:

# %%
orig_model_ys=model.predict(X_test)
optimizer_ys=optimizer.predict(X_test, sensitive_features=df_test['Gender'])

# %%
comparison = {
    'Original model': orig_model_ys,
    'TresholdOptimizer': optimizer_ys
}

# %%
FairlearnDashboard(sensitive_features=df_test['Gender'],
                   sensitive_feature_names=['BinaryGender'],
                   y_true=df_test['Fall'].tolist(),
                   y_pred=comparison)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:
